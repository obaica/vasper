# %%
from pymatgen.electronic_structure.cohp import Cohp
from pymatgen.electronic_structure.plotter import CohpPlotter
from pymatgen.io.lobster import Cohpcar


# COHPCAR_path = "/home/inoue/vega/mizo_lobster/COHPCAR.lobster"
COHPCAR_path = "COHPCAR.lobster"
cohpcar = Cohpcar(filename=COHPCAR_path)
cdata = cohpcar.cohp_data
cdata_processed = {}
for key in cdata:
    c = cdata[key]
    c["efermi"] = 0
    c["energies"] = cohpcar.energies
    c["are_coops"] = False
    cdata_processed[key] = Cohp.from_dict(c)
cp = CohpPlotter()
cp.add_cohp_dict(cdata_processed)
x = cp.get_plot()
x.ylim([-50, 20])
x.show()

# %%
cdata
# Out:
# {'average': {'COHP': {<Spin.up: 1>: array([0., 0., 0., ..., 0., 0., 0.])},
#   'ICOHP': {<Spin.up: 1>: array([ 0.,  0.,  0., ..., -0., -0., -0.])},
#   'efermi': 0,
#   'energies': array([-50.03574, -49.9857 , -49.93567, ...,  19.91422,  19.96426,
#           20.0143 ]),
#   'are_coops': False},
#  '1': {'COHP': {<Spin.up: 1>: array([0., 0., 0., ..., 0., 0., 0.])},
#   'ICOHP': {<Spin.up: 1>: array([ 0.,  0.,  0., ..., -0., -0., -0.])},
#   'length': 2.3394717083517262,
#   'sites': (0, 1),
#   'efermi': 0,
#   'energies': array([-50.03574, -49.9857 , -49.93567, ...,  19.91422,  19.96426,
#           20.0143 ]),
#   'are_coops': False}}

# %%
from pymatgen.electronic_structure.cohp import Cohp
from pymatgen.electronic_structure.plotter import CohpPlotter
from pymatgen.io.lobster import Cohpcar


#COHPCAR_path = "/home/inoue/vega/mizo_lobster/COHPCAR.lobster"
COHPCAR_path = "COHPCAR.lobster"
cohpcar = Cohpcar(filename=COHPCAR_path)
cdata = cohpcar.cohp_data
cdata_processed = {}
for key in cdata:
    c = cdata[key]
    c["efermi"] = 0
    c["energies"] = cohpcar.energies
    c["are_coops"] = False
    cdata_processed[key] = Cohp.from_dict(c)
cp = CohpPlotter()
cp.add_cohp_dict(cdata_processed)
x = cp.get_plot()
x.ylim([-50, 20])
x.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-50676999dd4e> in <module>
#       6 #COHPCAR_path = "/home/inoue/vega/mizo_lobster/COHPCAR.lobster"
#       7 COHPCAR_path = "COHPCAR.lobster"
# ----> 8 cohpcar = Cohpcar(filename=COHPCAR_path)
#       9 cdata = cohpcar.cohp_data
#      10 cdata_processed = {}
#
# ~/.pyenv/versions/anaconda3-5.3.1/envs/conda/lib/python3.6/site-packages/pymatgen/io/lobster.py in __init__(self, are_coops, filename)
#      80                 else "COHPCAR.lobster"
#      81
# ---> 82         with zopen(filename, "rt") as f:
#      83             contents = f.read().split("\n")
#      84
#
# ~/.pyenv/versions/anaconda3-5.3.1/envs/conda/lib/python3.6/site-packages/monty/io.py in zopen(filename, *args, **kwargs)
#      69         return gzip.open(filename, *args, **kwargs)
#      70     else:
# ---> 71         return io.open(filename, *args, **kwargs)
#      72
#      73
#
# FileNotFoundError: [Errno 2] No such file or directory: 'COHPCAR.lobster'

# %%
from pymatgen.electronic_structure.cohp import Cohp
from pymatgen.electronic_structure.plotter import CohpPlotter
from pymatgen.io.lobster import Cohpcar


#COHPCAR_path = "/home/inoue/vega/mizo_lobster/COHPCAR.lobster"
COHPCAR_path = 
cohpcar = Cohpcar(filename=COHPCAR_path)
cdata = cohpcar.orb_res_cohp['1']
cdata_processed = {}
for key in cdata:
    c = cdata[key]
    c["efermi"] = 0
    c["energies"] = cohpcar.energies
    c["are_coops"] = False
    cdata_processed[key] = Cohp.from_dict(c)
cp = CohpPlotter()
cp.add_cohp_dict(cdata_processed)
x = cp.get_plot()
x.ylim([-50, 20])
x.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-1ffe30b83809> in <module>
#       6 #COHPCAR_path = "/home/inoue/vega/mizo_lobster/COHPCAR.lobster"
#       7 COHPCAR_path = "COHPCAR.lobster"
# ----> 8 cohpcar = Cohpcar(filename=COHPCAR_path)
#       9 cdata = cohpcar.orb_res_cohp['1']
#      10 cdata_processed = {}
#
# ~/.pyenv/versions/anaconda3-5.3.1/envs/conda/lib/python3.6/site-packages/pymatgen/io/lobster.py in __init__(self, are_coops, filename)
#      80                 else "COHPCAR.lobster"
#      81
# ---> 82         with zopen(filename, "rt") as f:
#      83             contents = f.read().split("\n")
#      84
#
# ~/.pyenv/versions/anaconda3-5.3.1/envs/conda/lib/python3.6/site-packages/monty/io.py in zopen(filename, *args, **kwargs)
#      69         return gzip.open(filename, *args, **kwargs)
#      70     else:
# ---> 71         return io.open(filename, *args, **kwargs)
#      72
#      73
#
# FileNotFoundError: [Errno 2] No such file or directory: 'COHPCAR.lobster'

# %%
cdata_processed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-46ff665b7234> in <module>
# ----> 1 cdata_processed
#
# NameError: name 'cdata_processed' is not defined
